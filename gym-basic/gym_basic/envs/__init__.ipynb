# %%
# !pip install ipynb

# %%
from ipynb.fs.full.basic_env import DroneMaze
from ipynb.fs.full.basic_env_2 import BasicEnv2
import matplotlib.pyplot as plt

env = DroneMaze()
obs = env.reset()
plt.imshow(obs)
